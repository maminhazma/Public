# %% [markdown]
# ### Assignment-1 Minhaz 071023

# %% [markdown]
# ### Calling libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### 1. Reading dataset to python environment (Calling a data file to the programme)
# assign dataset name to 'data'

# %%
data = pd.read_excel("C:\Minhaz Local files\DSA\DSA - Data_base\iris.xlsx")

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 2. To display the columns in the dataset

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ### 3. Calculate the mean of each column of the dataset

# %%
data.mean()
# Out:
# C:\Users\mamin\AppData\Local\Temp\ipykernel_13320\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ### 4. Check for the null values present in the dataset

# %%
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 5.Perform meaningful visualizations using the dataset. Bring at least 3 visualizations

# %%
sns.lineplot(x='SL',y='Classification',data=data)
# Out:
# <Axes: xlabel='SL', ylabel='Classification'>

# %%
sns.lineplot(x='Classification',y='SL',hue='SW', data=data)
# Out:
# <Axes: xlabel='Classification', ylabel='SL'>

# %%
sns.scatterplot(x='Classification',y='SL',hue='SW', data=data)
# Out:
# <Axes: xlabel='Classification', ylabel='SL'>
